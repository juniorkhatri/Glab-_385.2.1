# %% [markdown]
# # List Notes & Practice
#
# ### Steps to Create Enc & ipynb (python notebook)
# 1. Create project folder
# 2. Open project folder in VSC
# 3. Verify your explorer tab and terminal are in the right place
# **** NO NESTED REPOSITORIES OR PROJECTS ****
# 4. (optional) initialize repo if pushing to github
# 5.  To create virtual env
#     - in terminal run: `python3 -m venv .venv`
#     *** If it fails, delete and run again ***
# 6.  Create `.gitignore` file at the ROOT of the project (next to the .venv, NOT IN)
# 7.  Document `.venv/` inside `.gitignore`
# 8.  Activate env
#     -   In terminal: `source .venv/Scripts/activate`
#     -   In terminal: `source .venv/bin/activate`
# 8.  Install ipykernel
#     -   In terminal: `pip install ipykernel`
# 9.  Create `.ipynb` file
# 10. Select Kernel (top right of ipynb file once open)
#     -   select the env you created (should be reccommended with a star)

# %%
print('Something More')
# Out:
# Something More

# %% [markdown]
# #### Data Collections
# - lists (arrays) - indexed collection. Have order and stay in order. Numbered by index
# - dictionaries (dict) - objects - keyed collection. Having no order, use a key to access information.
# - tuples - records (rows of a table), fixed length and specific order of values.

# %% [markdown]
# ### String
#
#  - Collection of single characters.
#  - Data access within lists and strings is IDENTICAL
#  - Index numbers to access values

# %%
greet = 'Hello, World'

# print the first value in a string/list
print(greet[0])
print(greet[1])
print(greet[2])
# Out:
# H
# e
# l

# %% [markdown]
# ### Python Indexing operator
# - can be used with strings and lists
# -`[start : stop : step]`
# - by default, if we don't inclue the step, its 1

# %%
print(greet[ : :-1])
# Out:
# dlroW ,olleH

# %% [markdown]
# ### Type () function
# - tells us what data type a variable is
# - `type(value) ->  data type

# %%
print(type(greet))
print(type(13))
print(type(True))
print(type(13.2))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %% [markdown]
# ### Typecasting Functions (to change the datatype of)
# - `str()`- turns anything into a string
# - `float()`- turns value into a float if possible
# - `int()` - turns value into a int if possible

# %%
age ='30'
print(type(age))

# If you permmenantly want to change a variable you have to re-assing it
age =int(age)

print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ### Methods - built in functions to python objects (everything in python is technically an object), for different datatypes/objects/modules
# - functions that are connected to variables of every type
# - defined with a period at the end of a varibale name, followed by the method
# - end with parenthases to invoke (run,execute) the method (function)

# %%
print(greet.upper())
print(greet.split())
# Out:
# HELLO, WORLD
# ['Hello,', 'World']

# %% [markdown]
# ## Lists - indexed collections
# - Numbered indexes
# - Start counting at 0
# - Any data type can be in a list
# - A list can be made of multiple different data types
# - No-fixed length (mutable - it can be changed)
# - syntax -`[ ]` with comma separted values

# %%
people = ['Carolyn', 'Joe','Dylan','Akorede']

# %%
print (people [0:])
print(len(people))
# Out:
# ['Carolyn', 'Joe', 'Dylan', 'Akorede']
# 4

# %%
fun = []

while True:
    ans = input('Give me a number')
    fun.append(ans)
    if(ans == 100):
        break

    print(fun)
# Out:
# ['']
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Types of Error:
# - `IndexError - out of range
# - `TypeError`- wrong type in a list, wrong type in an operation
# - `SyntaxError` - can't understand code structure, incorrect code grammer
# - `NameError` - Variable/function is not defined
# - `ValueError` - Correct type, invalid value
# - `Key Error` - Dictionary Key that doesn't
# - `Attribute Error` - Object doesn't have the attribute/method you are tyring to use
# - `Indentation Error` - Incorrect Indentation
# - `UnboundLocalError` - Trying to access a variable before assignment
# - `FileNotFoundError`
# - `ImportError`
# - `ModuleNotError`
# - `ZeroDivisionError`

# %%
# people[100] # Index Error
# people[1.5] # Type Error
# if x > 5: print(x) # Name Error
# if x > 5 print(x) # Syntax Error
# int('hello') # Value Error
# me ={}
# me['Name'] # Key Error
# 'hello'.append('goodbye') # AttributeError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # people[100]
# ----> 2 people[1.5]
#
# NameError: name 'people' is not defined

# %% [markdown]
# # Modiyfing Lists

# %%
animals =['Emu', 'Chipmunk','Buffalo', 'Goat']
print(animals)

animals[1] = 'Squirrel'

print(animals)
# Out:
# ['Emu', 'Chipmunk', 'Buffalo', 'Goat']
# ['Emu', 'Squirrel', 'Buffalo', 'Goat']

# %% [markdown]
# # .append() - add 1 element to the end of a list
# # .prepened() - add 1 element to the begning of a list
# # .extend() - add multiple items to the end of a list
# # .inset() - add items to a specified index of a list
